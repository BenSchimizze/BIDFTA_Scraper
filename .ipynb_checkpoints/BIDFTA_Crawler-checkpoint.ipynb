# %% [markdown]
# # Usage
#
# **Create new Bidfta class. On init, parses the main BIDFTA website.**
#
# ```
# bid = Bidfta()
# ```
#
# **Default includes all auction sites. Invoke method cincy_only() to reduce auctions to only Cincinnati**
#
# ```
# bid.cincy_only()
# ```
#
# **Optional method prints all base auction CGI's**
#
# ```
# bid.print_all_loc()
# ```
#
# **Method parse_auctions() crawls thru auction dictionary and publishes to an SQLite db. Returns open SQLite cursor for search**
#
# ```
# c = bid.parse_auctions()
# ```
#
# **Example search function**
# ```
# c.execute("""SELECT * FROM items
#              WHERE description like '%drone%'
#              ORDER BY msrp desc
#             """)
# c.fetchall()```

# %% [markdown]
# ### TODO:
# 1. Pull in auction end time. Not just date.
# 2. Search engine instead of SQL?

# %%
import requests, bs4
import os
import re
from datetime import datetime
import sqlite3
import selenium
from selenium import webdriver
import time
from functools import reduce
"""os.environ['http_proxy'] = "http://PITC-Zscaler-Americas-Cincinnati3PR.proxy.corporate.ge.com:80" 
os.environ['HTTP_PROXY'] = "http://PITC-Zscaler-Americas-Cincinnati3PR.proxy.corporate.ge.com:80"
os.environ['https_proxy'] = "http://PITC-Zscaler-Americas-Cincinnati3PR.proxy.corporate.ge.com:80"
os.environ['HTTPS_PROXY'] = "http://PITC-Zscaler-Americas-Cincinnati3PR.proxy.corporate.ge.com:80"""
# Out:
# 'os.environ[\'http_proxy\'] = "http://PITC-Zscaler-Americas-Cincinnati3PR.proxy.corporate.ge.com:80" \nos.environ[\'HTTP_PROXY\'] = "http://PITC-Zscaler-Americas-Cincinnati3PR.proxy.corporate.ge.com:80"\nos.environ[\'https_proxy\'] = "http://PITC-Zscaler-Americas-Cincinnati3PR.proxy.corporate.ge.com:80"\nos.environ[\'HTTPS_PROXY\'] = "http://PITC-Zscaler-Americas-Cincinnati3PR.proxy.corporate.ge.com:80'

# %%
# Optional test whether connection works...
from selenium import webdriver

driver = webdriver.Chrome()
driver.get('http://pythonscraping.com/pages/javascript/ajaxDemo.html')
time.sleep(3)
print(driver.find_element_by_id('content').text)
driver.close()
# Out:
# Here is some important text you want to retrieve!
# A button to click!

# %%
class Bidfta:
    def __init__(self):
        self.chrome_options = webdriver.chrome.options.Options()  
        self.chrome_options.add_argument("--headless")
        self.t0 = time.time()
        self.main_url = 'http://bidfta.bidqt.com/BidFTA/#/Main'
        main_driver = self.open_main_page()
        self.auction_dict = self.create_auction_dict(main_driver)
        main_driver.close()
        self.error_dict = {}
        print('Done parsing main site. Found {} auctions'.format(len(self.auction_dict.keys())))
        print('... in {:.2f} seconds'.format(time.time()-self.t0))

    def print_all_loc(self):
        cgi_list = sorted(self.auction_dict.keys())
        for item in cgi_list:
            print(item)
            
    def cincy_only(self):
        cincy_list = ['broadwell','seymour','school','waycross','mcmann']
        del_list = []
        for key in self.auction_dict.keys():
            matchbool = any([li in key for li in cincy_list])
            if not matchbool:
                del_list.append(key)
        for key in del_list:
            del self.auction_dict[key]
        
    def open_main_page(self):
        driver = webdriver.Chrome(chrome_options = self.chrome_options)
        driver.get(self.main_url)
        time.sleep(3)
        
        links = driver.find_element_by_tag_name('main').find_elements_by_tag_name('a')
        
        while links[-1].is_displayed():
            links[-1].click()
            time.sleep(3)
            links = driver.find_element_by_tag_name('main').find_elements_by_tag_name('a')
        
        return driver
    
    def create_auction_dict(self, driver):
        soup_main = bs4.BeautifulSoup(driver.page_source, 'html.parser')
        desc_list = soup_main.findAll('label', {'name':'AuctionDescription'})

        auction_dict = {}
        for auction in desc_list:
            cgi = auction.previous_sibling.find('a')['href'].split('?')[1]
            auction_dict[cgi] = {}
            auction_dict[cgi]['auction_uri'] = 'https://bid.bidfta.com/cgi-bin/mnlist.cgi?' + cgi + '/category/ALL'
            auction_dict[cgi]['location'] = auction.text
            auction_dict[cgi]['endtime'] = auction.next_sibling.text.split(" ")[1]

        return auction_dict

    def parse_auctions(self, max_ = 0):
        cursor = self.create_item_db()
        n_auctions = len(self.auction_dict.keys())
        i = 0
        auction_driver = self.create_driver()
        for auction in self.auction_dict.keys():
            if max_==0 or i < max_:
                adict = self.auction_dict[auction]
                url = adict['auction_uri']
                try:
                    auction_driver.get(url)
                except :
                    print('Unable to parse {}/{}: {}'.format(i+1,n_auctions,url))
                    print('Continuing')
                    self.error_dict[auction] = self.auction_dict[auction]
                    i += 1
                    continue
                print('Parsing {}/{}: {}'.format(i+1,n_auctions,url))
                t1 = time.time()
                self.update_page(auction_driver)
                auction_base_info = (adict.get('auction_uri'), adict.get('location'), adict.get('endtime'))
                self.write_items_to_db(auction_driver, auction_base_info, cursor)
                print('... in {:.2f} seconds'.format(time.time() - t1))
                print('... total time: {:.2f} seconds'.format(time.time()-self.t0))
                i += 1
            else:
                break
        return cursor
    
    def create_item_db(self):
        conn = sqlite3.connect('bidfta.db')
        c = conn.cursor()
        c.execute('DROP TABLE items')
        c.execute('''CREATE TABLE items
                     (
                     auction_uri text,
                     auction_loc text,
                     auction_endtime date,
                     brand text,
                     model text,
                     description text,
                     additional text,
                     msrp real,
                     price real,
                     uri text)''')
        return c
    
    def create_driver(self):
        driver = webdriver.Chrome(chrome_options = self.chrome_options)
        #driver.set_page_load_timeout(60)
        time.sleep(3)
        return driver

    def build_element_string(self, driver):
        # Builds list of all elements within auction. This feeds a page update to put all elements on one page.
        build_flag = True
        start_p = 'p1'
        item_str = ""
        while build_flag:
            try:
                item_str += driver.find_element_by_name(start_p).get_attribute("value")
                start_p = start_p[0] + str(int(start_p[1])+1)
            except:
                build_flag = False
        return item_str

    def update_page(self, driver):
        # Updates then clicks the p2 button to load all items on one page
        item_str = self.build_element_string(driver)
        try:
            elem = driver.find_elements_by_name("p2")[2]
            driver.execute_script("arguments[0].setAttribute('value','" + item_str + "')", elem)
            driver.find_element_by_xpath("//input[@value='p2'][@name='page']").click()
        except:
            return None
        return None
    
    def create_item_list_in_soup(self, driver):
        soup = bs4.BeautifulSoup(driver.page_source, 'html.parser')
        item_list = (soup.find('table',id='DataTable')
                         .findAll('tr', class_='DataRow')
                    )
        return item_list
    
    def create_dict_one_item(self, item):
        item_dict = {}
        item_dict['uri'] = "https://bid.bidfta.com" + item.find('a').get('href')
        item_dict['price'] = item.findAll('td')[5].getText()
        text = str(item.findAll('td')[2])
        re_breaks = re.compile("<br/>")
        re_bolds = re.compile("<b>(.*?)</b>")
        re_eol = re.compile(": (.*)$")
        txt = re_breaks.split(text)
        for row in txt:
            try:
                label = re_bolds.search(row).groups()[0]
                val = re_eol.search(row).groups()[0]
                item_dict[label] = val
            except:
                pass
        return item_dict


    def write_items_to_db(self, driver, base_tuple, c):
        item_list = self.create_item_list_in_soup(driver)
        
        for item in item_list:
            item_dict = self.create_dict_one_item(item)
            pull_list = ["Item Brand","Model","Item Desc","Additional Info","MSRP","price","uri"]
            output_tuple = tuple(item_dict.get(key) for key in pull_list)
            output_tuple = (*base_tuple, *output_tuple)
            c.execute('INSERT INTO items VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?)',output_tuple)

# %%
bid = Bidfta()
bid.cincy_only()
#c = bid.parse_auctions()
# Out:
# Done parsing main site. Found 371 auctions
# ... in 12.68 seconds

# %%
bid.print_all_loc()
# Out:
# broadwellv112
# broadwellv123
# broadwellv129
# broadwellv131
# broadwellv132
# broadwellv133
# broadwellv134
# broadwellv135
# broadwellv28
# broadwellv31
# broadwellv32
# broadwellv42
# broadwellv43
# broadwellv48
# broadwellv51
# broadwellv572
# broadwellv597
# broadwellv6
# broadwellv88
# mcmann1473
# mcmann1477
# mcmann1479
# mcmann1483
# mcmann1485
# mcmann1494
# mcmann1502
# mcmann1503
# mcmann1504
# mcmann1505
# mcmann1507
# mcmann1508
# mcmann1509
# mcmann1510
# mcmann1511
# mcmann1512
# mcmann1513
# mcmann1514
# mcmann1515
# mcmann1516
# schooliv1015
# schooliv549
# schooliv913
# schooliv916
# schooliv923
# schooliv930
# schooliv939
# schooliv942
# schooliv943
# schooliv947
# schooliv950
# schooliv951
# schooliv952
# schooliv953
# schooliv954
# schooliv957
# schooliv959
# schooliv960
# schooliv961
# schooliv963
# schooliv964
# schooliv965
# schooliv967
# schooliv969
# schooliv970
# schooliv974
# schooliv975
# schooliv976
# schooliv977
# schooliv979
# schooliv980
# schooliv981
# schooliv982
# schooliv983
# schooliv984
# seymouriii1123
# seymouriii1151
# seymouriii1159
# seymouriii1167
# seymouriii1168
# seymouriii1175
# seymouriii1186
# seymouriii1206
# seymouriii1207
# seymouriii1251
# seymouriii1254
# seymouriii1256
# seymouriii1257
# seymouriii1258
# seymouriii1260
# seymouriii1267
# seymouriii1269
# seymouriii1302
# seymouriii1308
# seymouriii1310
# seymouriii1311
# seymouriii1312
# seymouriii1313
# seymouriii1316
# seymouriii1320
# seymouriii1321
# seymouriii1323
# seymouriii1343
# seymouriii844
# seymouriii845
# seymouriii847
# waycross1335
# waycross1414
# waycross1415
# waycross1416
# waycross1425
# waycross1427
# waycross1433
# waycross1441

# %%
c = bid.parse_auctions()
# Out:
# Parsing 1/127: https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1310/category/ALL
# ... in 6.14 seconds
# ... total time: 31.11 seconds
# Parsing 2/127: https://bid.bidfta.com/cgi-bin/mnlist.cgi?broadwellv572/category/ALL
# ... in 4.69 seconds
# ... total time: 37.04 seconds
# Parsing 3/127: https://bid.bidfta.com/cgi-bin/mnlist.cgi?waycross1425/category/ALL
# ... in 0.10 seconds
# ... total time: 37.85 seconds
# Parsing 4/127: https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1308/category/ALL
# ... in 2.24 seconds
# ... total time: 42.72 seconds
# Parsing 5/127: https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv947/category/ALL
# ... in 0.13 seconds
# ... total time: 44.26 seconds
# Parsing 6/127: https://bid.bidfta.com/cgi-bin/mnlist.cgi?broadwell
WHITE',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   299.99,
#   0.01,
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?mcmann1502/MC1158676'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?broadwellv51/category/ALL',
#   'Broadwell Road, Cincinnati OH',
#   '4/24/2018',
#   'PROMARK',
#   'P70',
#   'PROMARK P70 DRONE WITH 3D VR GOGGLES AND HD CAMERA, WHITE*****LOTTER MUST TAKE OWN PHOTOS',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   299.99,
#   0.06,
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?broadwellv51/CP198208'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?broadwellv43/category/ALL',
#   'Broadwell Road, Cincinnati OH',
#   '4/24/2018',
#   'PROMARK',
#   'P70',
#   'PROMARK P70 DRONE WITH 3D VR GOGGLES AND HD CAMERA, WHITE',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   299.99,
#   0.06,
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?broadwellv43/CP178892'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv951/category/ALL',
#   'School Road, Cincinnati OH',
#   '4/24/2018',
#   'PROMARK',
#   'P70',
#   'PROMARK P70 DRONE WITH 3D VR GOGGLES AND HD CAMERA, WHITE',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   299.99,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv951/NP234439'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1312/category/ALL',
#   'Seymour Ave, Cincinnati OH',
#   '4/24/2018',
#   'PROMARK',
#   'P70',
#   'PROMARK P70 DRONE WITH 3D VR GOGGLES AND HD CAMERA, ',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   299.99,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1312/MC1148745'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1312/category/ALL',
#   'Seymour Ave, Cincinnati OH',
#   '4/24/2018',
#   'PROMARK',
#   'P70',
#   'PROMARK P70 DRONE WITH 3D VR GOGGLES AND HD CAMERA, ',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   299.99,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1312/MC1148833'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv950/category/ALL',
#   'School Road, Cincinnati OH',
#   '4/24/2018',
#   'PROMARK',
#   'P70',
#   'PROMARK P70 DRONE WITH 3D VR GOGGLES AND HD CAMERA, WHITE*****LOTTER MUST TAKE OWN PHOTOS',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   299.99,
#   5.55,
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv950/NP234267'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv950/category/ALL',
#   'School Road, Cincinnati OH',
#   '4/24/2018',
#   'PROMARK',
#   'P70',
#   'PROMARK P70 DRONE WITH 3D VR GOGGLES AND HD CAMERA, WHITE',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   299.99,
#   5.69,
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv950/NP234317'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?broadwellv42/category/ALL',
#   'Broadwell Road, Cincinnati OH',
#   '4/24/2018',
#   'PROMARK',
#   'P70',
#   'PROMARK P70 DRONE WITH 3D VR GOGGLES AND HD CAMERA, WHITE*****LOTTER MUST TAKE OWN PHOTOS',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   299.99,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?broadwellv42/CP178400'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1320/category/ALL',
#   'Seymour Ave, Cincinnati OH',
#   '4/25/2018',
#   'PROMARK',
#   'P70',
#   'PROMARK P70 DRONE WITH 3D VR GOGGLES AND HD CAMERA',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   299.99,
#   1.0,
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1320/NP233698'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv961/category/ALL',
#   'School Road, Cincinnati OH',
#   '4/25/2018',
#   'PROMARK',
#   'P70',
#   'PROMARK P70 DRONE WITH 3D VR GOGGLES AND HD CAMERA, WHITE',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   299.99,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv961/MC1113391'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1321/category/ALL',
#   'Seymour Ave, Cincinnati OH',
#   '4/25/2018',
#   'PROMARK',
#   'P70',
#   'PROMARK P70 DRONE WITH 3D VR GOGGLES AND HD CAMERA, WHITE',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   299.99,
#   0.6,
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1321/CP246803'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1123/category/ALL',
#   'Seymour Ave, Cincinnati OH',
#   '4/25/2018',
#   'PROMARK',
#   'P70',
#   'PROMARK P70 DRONE WITH 3D VR GOGGLES AND HD CAMERA, WHITE*****LOTTER MUST TAKE OWN PHOTOS',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   299.99,
#   1.0,
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1123/CP076492'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv954/category/ALL',
#   'School Road, Cincinnati OH',
#   '4/25/2018',
#   'PROMARK',
#   'P70',
#   'PROMARK P70 DRONE WITH 3D VR GOGGLES AND HD CAMERA, WHITE*****LOTTER MUST TAKE OWN PHOTOS',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   299.99,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv954/NP235267'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv954/category/ALL',
#   'School Road, Cincinnati OH',
#   '4/25/2018',
#   'PROMARK',
#   'P70',
#   'PROMARK P70 DRONE WITH 3D VR GOGGLES AND HD CAMERA, WHITE*****LOTTER MUST TAKE OWN PHOTOS',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   299.99,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv954/NP235170'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1151/category/ALL',
#   'Seymour Ave, Cincinnati OH',
#   '4/25/2018',
#   'PROMARK',
#   'P70',
#   'PROMARK P70 DRONE WITH 3D VR GOGGLES AND HD CAMERA, WHITE',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   299.99,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1151/CP068604'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv964/category/ALL',
#   'School Road, Cincinnati OH',
#   '4/25/2018',
#   'PROMARK',
#   'P70',
#   'PROMARK P70 DRONE WITH 3D VR GOGGLES AND HD CAMERA, WHITE',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   299.99,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv964/MC1114999'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv967/category/ALL',
#   'School Road, Cincinnati OH',
#   '4/25/2018',
#   'PROMARK',
#   'P70',
#   'PROMARK P70 DRONE WITH 3D VR GOGGLES AND HD CAMERA, WHITE',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   299.99,
#   0.06,
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv967/CP246524'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv965/category/ALL',
#   'School Road, Cincinnati OH',
#   '4/25/2018',
#   'PROMARK',
#   'P70',
#   'PROMARK P70 DRONE WITH 3D VR GOGGLES AND HD CAMERA, WHITE',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   299.99,
#   0.06,
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv965/CP246428'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?broadwellv132/category/ALL',
#   'Broadwell Road, Cincinnati OH',
#   '4/26/2018',
#   'PROMARK',
#   'P70',
#   'PROMARK P70 DRONE WITH 3D VR GOGGLES AND HD CAMERA, WHITE*****LOTTER MUST TAKE OWN PHOTOS',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   299.99,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?broadwellv132/CP235276'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv974/category/ALL',
#   'School Road, Cincinnati OH',
#   '4/26/2018',
#   'PROMARK',
#   'P70',
#   'PROMARK P70 DRONE WITH 3D VR GOGGLES AND HD CAMERA, WHITE',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   299.99,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv974/HQ874360'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv974/category/ALL',
#   'School Road, Cincinnati OH',
#   '4/26/2018',
#   'PROMARK',
#   'P70',
#   'PROMARK P70 DRONE WITH 3D VR GOGGLES AND HD CAMERA, WHITE',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   299.99,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv974/HQ874361'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv974/category/ALL',
#   'School Road, Cincinnati OH',
#   '4/26/2018',
#   'PROMARK',
#   'P70',
#   'PROMARK P70 DRONE WITH 3D VR GOGGLES AND HD CAMERA, WHITE',
#   'OPEN BOX',
#   299.99,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv974/HQ874391'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv952/category/ALL',
#   'School Road, Cincinnati OH',
#   '4/26/2018',
#   'PROMARK',
#   'P70',
#   'PROMARK P70 DRONE WITH 3D VR GOGGLES AND HD CAMERA, WHITE*****LOTTER MUST TAKE OWN PHOTOS',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   299.99,
#   0.06,
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv952/NP234654'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv952/category/ALL',
#   'School Road, Cincinnati OH',
#   '4/26/2018',
#   'PROMARK',
#   'P70',
#   'PROMARK P70 DRONE WITH 3D VR GOGGLES AND HD CAMERA, WHITE*****LOTTER MUST TAKE OWN PHOTOS',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   299.99,
#   0.06,
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv952/NP234717'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?broadwellv133/category/ALL',
#   'Broadwell Road, Cincinnati OH',
#   '4/26/2018',
#   'PROMARK',
#   'P70',
#   'PROMARK P70 DRONE WITH 3D VR GOGGLES AND HD CAMERA, WHITE',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   299.99,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?broadwellv133/CP235594'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv960/category/ALL',
#   'School Road, Cincinnati OH',
#   '4/26/2018',
#   'PROMARK',
#   'P70',
#   'PROMARK P70 DRONE WITH 3D VR GOGGLES AND HD CAMERA, WHITE',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   299.99,
#   0.06,
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv960/MC1113003'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?broadwellv134/category/ALL',
#   'Broadwell Road, Cincinnati OH',
#   '4/26/2018',
#   'PROMARK',
#   'P70',
#   'PROMARK P70 DRONE WITH 3D VR GOGGLES AND HD CAMERA, WHITE',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   299.99,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?broadwellv134/CP235888'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv965/category/ALL',
#   'School Road, Cincinnati OH',
#   '4/25/2018',
#   'KOLIBRI',
#   None,
#   'KOLIBRI DISCOVERY DELTA-RECON U818A WIFI FPV QUADCOPTER DRONE TACTICAL EDITION MILITARY MATTE GREEN UDI RC **EXTRA BATTERY INCLUDED**',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   299.95,
#   0.01,
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv965/CP246402'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?mcmann1505/category/ALL',
#   'McMann Road, Cincinnati OH',
#   '4/25/2018',
#   'SYMA',
#   None,
#   'SYMA X5C QUADCOPTER DRONE WITH HD CAMERA AND EXTRA BATTERY IN EXCLUSIVE BLACK/RED DESIGN',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   199.99,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?mcmann1505/MC1158970'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv965/category/ALL',
#   'School Road, Cincinnati OH',
#   '4/25/2018',
#   'HOLY STONE',
#   'F181',
#   'HOLY STONE F181C RC QUADCOPTER DRONE WITH HD CAMERA RTF 4 CHANNEL 2.4GHZ 6-GYRO WITH ALTITUDE HOLD FUNCTION,HEADLESS MODE AND ONE KEY RETURN HOME, COLOR BLACK',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   199.99,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv965/CP246475'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1159/category/ALL',
#   'Seymour Ave, Cincinnati OH',
#   '4/23/2018',
#   'PROMARK',
#   None,
#   'PROMARK P70 GPS SHADOW DRONE',
#   'APPEARS NEW',
#   179.0,
#   30.76,
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1159/CP178256'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?broadwellv31/category/ALL',
#   'Broadwell Road, Cincinnati OH',
#   '4/24/2018',
#   'PROMARK',
#   None,
#   'PROMARK P70 GPS SHADOW DRONE',
#   'APPEARS NEW',
#   179.0,
#   35.0,
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?broadwellv31/CP175530'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?broadwellv28/category/ALL',
#   'Broadwell Road, Cincinnati OH',
#   '4/24/2018',
#   'PROMARK',
#   None,
#   'PROMARK P70 GPS SHADOW DRONE',
#   'APPEARS NEW',
#   179.0,
#   30.0,
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?broadwellv28/CP175142'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?broadwellv28/category/ALL',
#   'Broadwell Road, Cincinnati OH',
#   '4/24/2018',
#   'PROMARK',
#   None,
#   'PROMARK P70 GPS SHADOW DRONE',
#   'APPEARS NEW',
#   179.0,
#   22.5,
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?broadwellv28/CP175188'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?broadwellv42/category/ALL',
#   'Broadwell Road, Cincinnati OH',
#   '4/24/2018',
#   'PROMARK',
#   None,
#   'PROMARK P70 GPS SHADOW DRONE',
#   'APPEARS NEW',
#   179.0,
#   30.0,
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?broadwellv42/CP178409'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv994/category/ALL',
#   'School Road, Cincinnati OH',
#   '4/25/2018',
#   'PROMARK',
#   None,
#   'PROMARK P70 GPS SHADOW DRONE',
#   'OPEN BOX',
#   179.0,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv994/HQ874752'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1123/category/ALL',
#   'Seymour Ave, Cincinnati OH',
#   '4/25/2018',
#   'PROMARK',
#   None,
#   'PROMARK P70 GPS SHADOW DRONE',
#   'APPEARS NEW',
#   179.0,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1123/CP076490'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1151/category/ALL',
#   'Seymour Ave, Cincinnati OH',
#   '4/25/2018',
#   'PROMARK',
#   None,
#   'PROMARK P70 GPS SHADOW DRONE',
#   'APPEARS NEW',
#   179.0,
#   0.01,
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1151/CP068609'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?mcmann1512/category/ALL',
#   'McMann Road, Cincinnati OH',
#   '4/25/2018',
#   'PROMARK',
#   None,
#   'DRONE - PROMARK - GPS SHADOW DRONE - PREMIER GPS-ENABLED DRONE WITH FOLLOW ME TECHNOLOGY - 6-AXIS GYROSCOPE FOR PANORAMIC SHOTS - LITHIUM BATTERIES INCLUDED - 720P WIFI CAMERA - INCLUDES VR GOGGLES',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   179.0,
#   0.06,
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?mcmann1512/TN067265'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv974/category/ALL',
#   'School Road, Cincinnati OH',
#   '4/26/2018',
#   'PROMARK',
#   None,
#   'PROMARK P70 GPS SHADOW DRONE',
#   'APPEARS NEW',
#   179.0,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv974/HQ874388'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv974/category/ALL',
#   'School Road, Cincinnati OH',
#   '4/26/2018',
#   'PROMARK',
#   None,
#   'PROMARK P70 GPS SHADOW DRONE',
#   'OPEN BOX',
#   179.0,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv974/HQ874390'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv974/category/ALL',
#   'School Road, Cincinnati OH',
#   '4/26/2018',
#   'PROMARK',
#   None,
#   'PROMARK P70 GPS SHADOW DRONE',
#   'APPEARS NEW',
#   179.0,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv974/HQ874392'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv965/category/ALL',
#   'School Road, Cincinnati OH',
#   '4/25/2018',
#   'GPX',
#   'DRW876',
#   'GPX 6-AXIS CONDOR PRO DRONE WITH WI-FI CAMERA, 4-CHANNEL DIRECTION CONTROL, 300-FOOT CONTROL DISTANCE (DRW876)',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   149.99,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv965/CP246390'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv950/category/ALL',
#   'School Road, Cincinnati OH',
#   '4/24/2018',
#   'AIR HOGS',
#   '6027815',
#   'AIR HOGS - STAR WARS X-WING VS. DEATH STAR, REBEL ASSAULT - RC DRONES',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   129.99,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv950/NP234347'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv965/category/ALL',
#   'School Road, Cincinnati OH',
#   '4/25/2018',
#   'SKY VIPER',
#   '1718',
#   'SKY VIPER 01601 HD STREAMING VIDEO DRONE TOY',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   99.99,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv965/CP246357'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv965/category/ALL',
#   'School Road, Cincinnati OH',
#   '4/25/2018',
#   'SKY VIPER',
#   '1718',
#   'SKY VIPER 01601 HD STREAMING VIDEO DRONE TOY',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   99.99,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv965/CP246453'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1310/category/ALL',
#   'Seymour Ave, Cincinnati OH',
#   '4/23/2018',
#   'PROMARK',
#   None,
#   'PROMARK P70-CW WARRIOR DRONE, BLACK',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   99.0,
#   3.45,
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1310/MC1153782'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1310/category/ALL',
#   'Seymour Ave, Cincinnati OH',
#   '4/23/2018',
#   'PROMARK',
#   None,
#   'PROMARK P70-CW WARRIOR DRONE, BLACK',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   99.0,
#   3.45,
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1310/MC1153792'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1310/category/ALL',
#   'Seymour Ave, Cincinnati OH',
#   '4/23/2018',
#   'PROMARK',
#   None,
#   'PROMARK P70-CW WARRIOR DRONE, BLACK',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   99.0,
#   3.21,
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1310/MC1153804'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1308/category/ALL',
#   'Seymour Ave, Cincinnati OH',
#   '4/23/2018',
#   'PROMARK',
#   None,
#   'PROMARK P70-CW WARRIOR DRONE, BLACK',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   99.0,
#   4.1,
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1308/MC1153270'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?broadwellv131/category/ALL',
#   'Broadwell Road, Cincinnati OH',
#   '4/23/2018',
#   'PROMARK',
#   None,
#   'PROMARK P70-CW WARRIOR DRONE, BLACK',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   99.0,
#   6.02,
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?broadwellv131/CP234838'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv942/category/ALL',
#   'School Road, Cincinnati OH',
#   '4/23/2018',
#   'PROMARK',
#   None,
#   'PROMARK P70-CW WARRIOR DRONE, BLACK',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   99.0,
#   12.5,
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv942/MC1149809'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv943/category/ALL',
#   'School Road, Cincinnati OH',
#   '4/23/2018',
#   'PROMARK',
#   None,
#   'PROMARK P70-CW WARRIOR DRONE, BLACK',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   99.0,
#   3.19,
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv943/MC1150403'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?broadwellv123/category/ALL',
#   'Broadwell Road, Cincinnati OH',
#   '4/23/2018',
#   'PROMARK',
#   None,
#   'PROMARK P70-CW WARRIOR DRONE, BLACK',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   99.0,
#   2.2,
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?broadwellv123/NP232062'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?broadwellv123/category/ALL',
#   'Broadwell Road, Cincinnati OH',
#   '4/23/2018',
#   'PROMARK',
#   None,
#   'PROMARK P70-CW WARRIOR DRONE, BLACK',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   99.0,
#   5.5,
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?broadwellv123/NP232140'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1186/category/ALL',
#   'Seymour Ave, Cincinnati OH',
#   '4/23/2018',
#   'PROMARK',
#   None,
#   'PROMARK P70-CW WARRIOR DRONE, BLACK',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   99.0,
#   2.22,
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1186/CP074749'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv953/category/ALL',
#   'School Road, Cincinnati OH',
#   '4/23/2018',
#   'PROMARK',
#   None,
#   'PROMARK P70-CW WARRIOR DRONE, BLACK',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   99.0,
#   0.11,
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv953/NP234826'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1206/category/ALL',
#   'Seymour Ave, Cincinnati OH',
#   '4/23/2018',
#   'PROMARK',
#   None,
#   'PROMARK P70-CW WARRIOR DRONE BLACK',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   99.0,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1206/TN087426'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1207/category/ALL',
#   'Seymour Ave, Cincinnati OH',
#   '4/23/2018',
#   'PROMARK',
#   None,
#   'PROMARK P70-CW WARRIOR DRONE, BLACK',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   99.0,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1207/TN087797'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?broadwellv48/category/ALL',
#   'Broadwell Road, Cincinnati OH',
#   '4/23/2018',
#   'PROMARK',
#   None,
#   'PROMARK P70-CW WARRIOR DRONE, BLACK*****LOTTER MUST TAKE THEIR OWN PHOTOS  ',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   99.0,
#   0.01,
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?broadwellv48/CP074530'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?broadwellv6/category/ALL',
#   'Broadwell Road, Cincinnati OH',
#   '4/24/2018',
#   'PROMARK',
#   None,
#   'PROMARK P70-CW WARRIOR DRONE, BLACK',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   99.0,
#   0.01,
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?broadwellv6/CP163531'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv939/category/ALL',
#   'School Road, Cincinnati OH',
#   '4/24/2018',
#   'PROMARK',
#   None,
#   'PROMARK P70-CW WARRIOR DRONE, BLACK',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   99.0,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv939/MC1149222'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?broadwellv32/category/ALL',
#   'Broadwell Road, Cincinnati OH',
#   '4/24/2018',
#   'PROMARK',
#   None,
#   'PROMARK P70-CW WARRIOR DRONE, BLACK',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   99.0,
#   0.06,
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?broadwellv32/CP175783'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1302/category/ALL',
#   'Seymour Ave, Cincinnati OH',
#   '4/24/2018',
#   'PROMARK',
#   None,
#   'PROMARK P70-CW WARRIOR DRONE, BLACK',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   99.0,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1302/MC1151407'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?broadwellv31/category/ALL',
#   'Broadwell Road, Cincinnati OH',
#   '4/24/2018',
#   'PROMARK',
#   None,
#   'PROMARK P70-CW WARRIOR DRONE, BLACK',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   99.0,
#   0.06,
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?broadwellv31/CP175533'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1311/category/ALL',
#   'Seymour Ave, Cincinnati OH',
#   '4/24/2018',
#   'PROMARK',
#   None,
#   'PROMARK P70-CW WARRIOR DRONE, BLACK',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   99.0,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1311/MC1148247'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?broadwellv51/category/ALL',
#   'Broadwell Road, Cincinnati OH',
#   '4/24/2018',
#   'PROMARK',
#   None,
#   'PROMARK P70-CW WARRIOR DRONE, BLACK*****LOTTER MUST TAKE THEIR OWN PHOTOS  ',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   99.0,
#   0.06,
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?broadwellv51/CP198210'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?broadwellv43/category/ALL',
#   'Broadwell Road, Cincinnati OH',
#   '4/24/2018',
#   'PROMARK',
#   None,
#   'PROMARK P70-CW WARRIOR DRONE, BLACK',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   99.0,
#   0.06,
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?broadwellv43/CP178870'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?broadwellv43/category/ALL',
#   'Broadwell Road, Cincinnati OH',
#   '4/24/2018',
#   'PROMARK',
#   None,
#   'PROMARK P70-CW WARRIOR DRONE, BLACK',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   99.0,
#   0.06,
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?broadwellv43/CP178833'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv951/category/ALL',
#   'School Road, Cincinnati OH',
#   '4/24/2018',
#   'PROMARK',
#   None,
#   'PROMARK P70-CW WARRIOR DRONE, BLACK',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   99.0,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv951/NP234440'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1312/category/ALL',
#   'Seymour Ave, Cincinnati OH',
#   '4/24/2018',
#   'PROPEL',
#   None,
#   'PROPEL VL-3592 MAXIMUM X15 HYBRID STUNT DRONE WITH HD CAMERA - SILVER',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   99.0,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1312/MC1148731'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1312/category/ALL',
#   'Seymour Ave, Cincinnati OH',
#   '4/24/2018',
#   'PROMARK',
#   None,
#   'PROMARK P70-CW WARRIOR DRONE, BLACK',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   99.0,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1312/MC1148742'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1312/category/ALL',
#   'Seymour Ave, Cincinnati OH',
#   '4/24/2018',
#   'PROMARK',
#   None,
#   'PROMARK P70-CW WARRIOR DRONE, BLACK',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   99.0,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1312/MC1148837'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv950/category/ALL',
#   'School Road, Cincinnati OH',
#   '4/24/2018',
#   'PROMARK',
#   None,
#   'PROMARK P70-CW WARRIOR DRONE, BLACK',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   99.0,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv950/NP234263'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv950/category/ALL',
#   'School Road, Cincinnati OH',
#   '4/24/2018',
#   'PROMARK',
#   None,
#   'PROMARK P70-CW WARRIOR DRONE, BLACK',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   99.0,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv950/NP234298'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv950/category/ALL',
#   'School Road, Cincinnati OH',
#   '4/24/2018',
#   'PROMARK',
#   None,
#   'PROMARK P70-CW WARRIOR DRONE, BLACK',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   99.0,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv950/NP234313'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?broadwellv42/category/ALL',
#   'Broadwell Road, Cincinnati OH',
#   '4/24/2018',
#   'PROMARK',
#   None,
#   'PROMARK P70-CW WARRIOR DRONE, BLACK',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   99.0,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?broadwellv42/CP178390'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1320/category/ALL',
#   'Seymour Ave, Cincinnati OH',
#   '4/25/2018',
#   'PROMARK',
#   None,
#   'PROMARK P70-CW WARRIOR DRONE, BLACK',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   99.0,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1320/NP233699'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv961/category/ALL',
#   'School Road, Cincinnati OH',
#   '4/25/2018',
#   'PROMARK',
#   None,
#   'PROMARK P70-CW WARRIOR DRONE, BLACK',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   99.0,
#   0.06,
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv961/MC1113376'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1321/category/ALL',
#   'Seymour Ave, Cincinnati OH',
#   '4/25/2018',
#   'PROMARK',
#   None,
#   'PROMARK P70-CW WARRIOR DRONE, BLACK',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   99.0,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1321/CP246843'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv954/category/ALL',
#   'School Road, Cincinnati OH',
#   '4/25/2018',
#   'PROMARK',
#   None,
#   'PROMARK P70-CW WARRIOR DRONE, BLACK*****LOTTER MUST TAKE THEIR OWN PHOTOS  ',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   99.0,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv954/NP235257'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv954/category/ALL',
#   'School Road, Cincinnati OH',
#   '4/25/2018',
#   'PROMARK',
#   None,
#   'PROMARK P70-CW WARRIOR DRONE, BLACK*****LOTTER MUST TAKE THEIR OWN PHOTOS  ',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   99.0,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv954/NP235199'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1269/category/ALL',
#   'Seymour Ave, Cincinnati OH',
#   '4/25/2018',
#   'PROMARK',
#   None,
#   'PROMARK P70-CW WARRIOR DRONE, BLACK',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   99.0,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1269/SY722197'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv965/category/ALL',
#   'School Road, Cincinnati OH',
#   '4/25/2018',
#   'PROMARK',
#   None,
#   'PROMARK P70-CW WARRIOR DRONE, BLACK',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   99.0,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv965/CP246394'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?broadwellv132/category/ALL',
#   'Broadwell Road, Cincinnati OH',
#   '4/26/2018',
#   'PROMARK',
#   None,
#   'PROMARK P70-CW WARRIOR DRONE, BLACK',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   99.0,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?broadwellv132/CP235275'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv974/category/ALL',
#   'School Road, Cincinnati OH',
#   '4/26/2018',
#   'PROMARK',
#   None,
#   'PROMARK P70-CW WARRIOR DRONE, BLACK',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   99.0,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv974/HQ874389'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv952/category/ALL',
#   'School Road, Cincinnati OH',
#   '4/26/2018',
#   'PROMARK',
#   None,
#   'PROMARK P70-CW WARRIOR DRONE, BLACK',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   99.0,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv952/NP234653'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?broadwellv133/category/ALL',
#   'Broadwell Road, Cincinnati OH',
#   '4/26/2018',
#   'PROMARK',
#   None,
#   'PROMARK P70-CW WARRIOR DRONE, BLACK',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   99.0,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?broadwellv133/CP235570'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv960/category/ALL',
#   'School Road, Cincinnati OH',
#   '4/26/2018',
#   'PROMARK',
#   None,
#   'PROMARK P70-CW WARRIOR DRONE',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   99.0,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv960/MC1112943'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv943/category/ALL',
#   'School Road, Cincinnati OH',
#   '4/23/2018',
#   'SKY VIPER',
#   '1732',
#   'SKY VIPER S1750 STUNT DRONE',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   54.99,
#   0.16,
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv943/MC1150430'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv943/category/ALL',
#   'School Road, Cincinnati OH',
#   '4/23/2018',
#   'BEST CHOICE PRODUCTS',
#   'SKY2913',
#   'BCP 4 CHANNEL 6-AXIS GYRO HEADLESS REMOTE CONTROL QUADCOPTER FPV RC DRONE WITH WIFI CAMERA FOR REAL TIME VIDEO, 2 CONTROL MODES',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   54.95,
#   1.11,
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv943/MC1150381'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1206/category/ALL',
#   'Seymour Ave, Cincinnati OH',
#   '4/23/2018',
#   'FORCE1',
#   None,
#   'UDI U45W DRONE CARRYING CASE - HARD DRONE CASE ACCESSORIES PACK FOR CARRYING A FORCE1 U45W BLUE JAY WI-FI DRONE QUADCOPTER (BLACK)',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   49.99,
#   2.8,
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1206/TN087411'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1311/category/ALL',
#   'Seymour Ave, Cincinnati OH',
#   '4/24/2018',
#   'LITTLE TIKES',
#   '646225',
#   'LITTLE TIKES MY FIRST DRONE TOY',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   42.99,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1311/MC1148291'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1311/category/ALL',
#   'Seymour Ave, Cincinnati OH',
#   '4/24/2018',
#   'SHARPER IMAGE',
#   None,
#   'SHARPER IMAGE 1002187 10INCH DRONE WITH CAMERA STREAMING',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   40.0,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1311/MC1148320'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv974/category/ALL',
#   'School Road, Cincinnati OH',
#   '4/26/2018',
#   'MOULD KING',
#   None,
#   'MINI RC HELICOPTER, MOULD KING SUPER-F REMOTE CONTROL QUADCOPTER DRONE 4CH 2.4GHZ 6-AXIS MINI DRONE RTF WITH HEADLESS MODE LED FLASHING (BLACK)',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   39.99,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv974/HQ874375'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv943/category/ALL',
#   'School Road, Cincinnati OH',
#   '4/23/2018',
#   'KOSIWUN',
#   None,
#   'KOSIWUN FQ777 124 MICRO POCKET DRONE 4CH 6AXIS GYRO WITH SWITCHABLE CONTROLLER AND 3D FLIP HEADLESS MODE MINI QUADCOPTER FOR KIDS TOYS BLACK',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   None,
#   1.11,
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv943/MC1150363'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?waycross1427/category/ALL',
#   'Civic Center, Cincinnati OH',
#   '4/23/2018',
#   'XFINITY',
#   None,
#   'DEPSTECH WATERPROOF BACKPACK CASE FOR DJI PHANTOM 3 PROFESSIONAL, ADVANCED, STANDARD, 4K QUADCOPTER DRONE AND ACCESSORIES-BLACK',
#   'BRAND NEW',
#   None,
#   4.05,
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?waycross1427/MC1148142'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1167/category/ALL',
#   'Seymour Ave, Cincinnati OH',
#   '4/23/2018',
#   None,
#   None,
#   'FREE WELL ACTION CAMERA CASE &amp; DRONE GEAR EASY SNORKEL, BLACK OR BLUE, LARGE TO XLARGE',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   None,
#   '9.23\nx 3 = 27.69',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1167/MC948868'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1186/category/ALL',
#   'Seymour Ave, Cincinnati OH',
#   '4/23/2018',
#   'CHEF RIMER',
#   None,
#   'CHEF RIMER DRONE LANDING PAD 30" 75CM UNIVERSAL - QUADCOPTER DJI MAVIC SPARK PRO INSPIRE 1 GOPRO KARMA RC AIRCRAFT ANTEL ROBOTIC PARROT PHANTOM 2 3 4 REMOTE CONTROL HELICOPTERS 3DR SOLO LAUNCH HELIPAD',
#   'BRAND NEW',
#   None,
#   0.01,
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1186/CP074704'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?broadwellv48/category/ALL',
#   'Broadwell Road, Cincinnati OH',
#   '4/23/2018',
#   None,
#   None,
#   'CHEF RIMER DRONE LANDING PAD UNIVERSALLY ',
#   'BRAND NEW',
#   None,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?broadwellv48/CP074506'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1311/category/ALL',
#   'Seymour Ave, Cincinnati OH',
#   '4/24/2018',
#   None,
#   None,
#   'ASSORTED DRONES ',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   None,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1311/MC1148296'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1311/category/ALL',
#   'Seymour Ave, Cincinnati OH',
#   '4/24/2018',
#   None,
#   None,
#   'SKY VIPER BLACK AND GREEN  DRONE',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   None,
#   0.01,
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1311/MC1148327'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1312/category/ALL',
#   'Seymour Ave, Cincinnati OH',
#   '4/24/2018',
#   'HUBSAN',
#   'H107C G 480P',
#   'HUBSAN H107C X4 QUADCOPTER DRONE WITH CAMERA (BLACK/GREEN)',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   None,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1312/MC1148761'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1312/category/ALL',
#   'Seymour Ave, Cincinnati OH',
#   '4/24/2018',
#   None,
#   None,
#   'SMALL BLACK DRONE DX2',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   None,
#   0.01,
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1312/MC1148776'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1312/category/ALL',
#   'Seymour Ave, Cincinnati OH',
#   '4/24/2018',
#   None,
#   None,
#   'BLUE METALLIC DRONE ',
#   'DAMAGED, SEE ADDITIONAL PICTURES',
#   None,
#   0.01,
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1312/MC1148779'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1312/category/ALL',
#   'Seymour Ave, Cincinnati OH',
#   '4/24/2018',
#   'KINGPOW',
#   None,
#   'RC DRONE,KINGPOW MINI RC QUADCOPTER FPV VR WIFI REMOTE CONTROL DRONE WITH 0.3MP HD CAMERA RC HELICOPTER',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   None,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1312/MC1148818'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1312/category/ALL',
#   'Seymour Ave, Cincinnati OH',
#   '4/24/2018',
#   None,
#   None,
#   '3D ROLL DRONE ',
#   'APPEARS NEW',
#   None,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?seymouriii1312/MC1148840'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?mcmann1503/category/ALL',
#   'McMann Road, Cincinnati OH',
#   '4/25/2018',
#   'HOLY STONE',
#   None,
#   'HOLY STONE HS110 FPV RC DRONE WITH CAMERA 720P HD LIVE VIDEO WIFI 2.4GHZ 4CH 6-AXIS GYRO RC QUADCOPTER WITH ALTITUDE HOLD, ONE KEY RETURN AND HEADLESS MODE FUNCTION RTF, COLOR GREEN',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   None,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?mcmann1503/MC1158718'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?mcmann1512/category/ALL',
#   'McMann Road, Cincinnati OH',
#   '4/25/2018',
#   None,
#   None,
#   'BUNDLE BOX PROMARK DRONE 2 XS THE BID ',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   None,
#   '0.01\nx 2 = 0.02',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?mcmann1512/TN067324'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv965/category/ALL',
#   'School Road, Cincinnati OH',
#   '4/25/2018',
#   None,
#   None,
#   'SHARPER IMAGE DRONE',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   None,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv965/CP246465'),
#  ('https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv965/category/ALL',
#   'School Road, Cincinnati OH',
#   '4/25/2018',
#   None,
#   None,
#   'ASSORTED DRONES',
#   'OPEN BOX, SEE ADDITIONAL PICTURES',
#   None,
#   '\xa0',
#   'https://bid.bidfta.com/cgi-bin/mnlist.cgi?schooliv965/CP246471')]
